# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
from mpl_toolkits import mplot3d
from hdbscan import HDBSCAN

#https://anaconda.org/conda-forge/hdbscan
#conda install -c conda-forge hdbscan

# %%
df_cluster_hdbscan = np.load('../bases/clusterable_data.npy')
df_cluster_hdbscan
# Out:
# array([[-0.12153499, -0.22876337],
#        [-0.22093687, -0.25251088],
#        [ 0.1259037 , -0.27314321],
#        ...,
#        [ 0.50243143, -0.3002958 ],
#        [ 0.53822256,  0.19412199],
#        [-0.08688887, -0.2092721 ]])

# %%
hdbscan = HDBSCAN(min_cluster_size=20,
                 min_samples=10)
                 
preds = hdbscan.fit_predict(df_cluster_hdbscan)

# %%
#Para Dataframe
df_cluster_hdbscan = pd.DataFrame(df_cluster_hdbscan)
df_cluster_hdbscan.head()
# Out:
#           0         1
# 0 -0.121535 -0.228763
# 1 -0.220937 -0.252511
# 2  0.125904 -0.273143
# 3 -0.164537 -0.222244
# 4 -0.180824 -0.211075

# %%
#Ajuste
df_cluster_hdbscan = df_cluster_hdbscan.rename(columns={0:'x',
                                                       1:'y'})
df_cluster_hdbscan.columns
# Out:
# Index(['x', 'y'], dtype='object')

# %%
#Graficamos
df_cluster_hdbscan.plot(kind='scatter', x='x', y='y', c=preds, cmap='Accent_r', figsize=(16,10))
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# # Conclusões
#
# Com base na visualização anterior, nosso algoritmo criou seis clusters e detectou o ruído do conjunto de dados (pontos cinza).
